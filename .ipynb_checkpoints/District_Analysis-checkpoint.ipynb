# %%
import os
import pandas as pd
import matplotlib .pyplot as plt
import numpy as np

# %%
cte_data = pd.read_csv("Clean_and_Combine.csv")
cte_data.head()
# Out:
#    DISTRICT  SERVICE                        SERVICEX  CTE_STUDENTS_2015  \
# 0      1902  3101100          PRECALCULUS (PRE CALC)                9.0
# 1      1902  3220300             ENGLISH III (ENG 3)               12.0
# 2      1902  3220400              ENGLISH IV (ENG 4)               10.0
# 3      1902  3310300   ECONOMICS W/EMPH FREE ENTERPR                3.0
# 4      1902  3330100  UNITED STATES GOVERNMENT (GOVT                3.0
#
#    CTE_HOURS_2015  CTE_AVG_2015  ALL_STUDENTS_2015  ALL_HOURS_2015  \
# 0            36.0           4.0               18.0            54.0
# 1            48.0           4.0               12.0            48.0
# 2            57.0           5.7               14.0            81.0
# 3             3.0           3.0                3.0             3.0
# 4             3.0           3.0                3.0             3.0
#
#    ALL_AVG_2015  CTE_STUDENTS_2016  ...  ALL_AVG_2017  CTE_STUDENTS_2018  \
# 0           3.0                9.0  ...           5.8               15.0
# 1           4.0               18.0  ...           5.8               15.0
# 2           5.8                7.0  ...           5.6               15.0
# 3           3.0               10.0  ...           3.0                6.0
# 4           3.0               12.0  ...           3.0                6.0
#
#    CTE_HOURS_2018  CTE_AVG_2018  ALL_STUDENTS_2018  ALL_HOURS_2018  \
# 0            45.0           3.0               15.0            45.0
# 1            90.0           6.0               17.0           102.0
# 2            81.0           5.4               15.0            81.0
# 3            18.0           3.0                6.0            18.0
# 4            18.0           3.0                6.0            18.0
#
#    ALL_AVG_2018    District  TEA District Type  TEA Description
# 0           3.0  CAYUGA ISD                  H            Rural
# 1           6.0  CAYUGA ISD                  H            Rural
# 2           5.4  CAYUGA ISD                  H            Rural
# 3           3.0  CAYUGA ISD                  H            Rural
# 4           3.0  CAYUGA ISD                  H            Rural
#
# [5 rows x 30 columns]

# %%
bins = [0, 2999999, 3200000, 3300000, 4000000, 2000000000]
group_labels = ["Misc","STEM","English","Social Sciences","CTE/Tech"]

# %%
cte_data["Course Type"] = pd.cut(cte_data["SERVICE"], bins, labels=group_labels)
cte_data.head()
# Out:
#    DISTRICT  SERVICE                        SERVICEX  CTE_STUDENTS_2015  \
# 0      1902  3101100          PRECALCULUS (PRE CALC)                9.0
# 1      1902  3220300             ENGLISH III (ENG 3)               12.0
# 2      1902  3220400              ENGLISH IV (ENG 4)               10.0
# 3      1902  3310300   ECONOMICS W/EMPH FREE ENTERPR                3.0
# 4      1902  3330100  UNITED STATES GOVERNMENT (GOVT                3.0
#
#    CTE_HOURS_2015  CTE_AVG_2015  ALL_STUDENTS_2015  ALL_HOURS_2015  \
# 0            36.0           4.0               18.0            54.0
# 1            48.0           4.0               12.0            48.0
# 2            57.0           5.7               14.0            81.0
# 3             3.0           3.0                3.0             3.0
# 4             3.0           3.0                3.0             3.0
#
#    ALL_AVG_2015  CTE_STUDENTS_2016  ...  CTE_STUDENTS_2018  CTE_HOURS_2018  \
# 0           3.0                9.0  ...               15.0            45.0
# 1           4.0               18.0  ...               15.0            90.0
# 2           5.8                7.0  ...               15.0            81.0
# 3           3.0               10.0  ...                6.0            18.0
# 4           3.0               12.0  ...                6.0            18.0
#
#    CTE_AVG_2018  ALL_STUDENTS_2018  ALL_HOURS_2018  ALL_AVG_2018    District  \
# 0           3.0               15.0            45.0           3.0  CAYUGA ISD
# 1           6.0               17.0           102.0           6.0  CAYUGA ISD
# 2           5.4               15.0            81.0           5.4  CAYUGA ISD
# 3           3.0                6.0            18.0           3.0  CAYUGA ISD
# 4           3.0                6.0            18.0           3.0  CAYUGA ISD
#
#    TEA District Type  TEA Description      Course Type
# 0                  H            Rural             STEM
# 1                  H            Rural          English
# 2                  H            Rural          English
# 3                  H            Rural  Social Sciences
# 4                  H            Rural  Social Sciences
#
# [5 rows x 31 columns]

# %%
district_types = cte_data["TEA Description"].value_counts()
district_types
# Out:
# Rural                            4908
# Other Central City Suburban      3749
# Non-metropolitan Stable          2937
# Major Suburban                   2446
# Other Central City               1754
# Independent Town                 1350
# Charter School Districts         1085
# Major Urban                      1044
# Non-metropolitan Fast Growing     569
# Name: TEA Description, dtype: int64

# %%
cte_focus = cte_data[cte_data['Course Type'] == "CTE/Tech"]
cte_focus.head()
# Out:
#     DISTRICT   SERVICE                     SERVICEX  CTE_STUDENTS_2015  \
# 6       1902  13009900  PROFESSIONAL COMMUNICATIONS                3.0
# 14      1904  13014300       HUMAN GROWTH & DEVELOP               14.0
# 15      1904  13020400               HEALTH SCIENCE                7.0
# 30      1906  13008400           ADVANCED ANIMATION                3.0
# 31      1906  13012100          BUSINESS MANAGEMENT                6.0
#
#     CTE_HOURS_2015  CTE_AVG_2015  ALL_STUDENTS_2015  ALL_HOURS_2015  \
# 6              3.0           3.0                3.0             3.0
# 14            42.0           3.0               14.0            42.0
# 15            14.0           2.0                7.0            14.0
# 30             3.0           3.0                3.0             3.0
# 31             6.0           6.0                6.0             6.0
#
#     ALL_AVG_2015  CTE_STUDENTS_2016  ...  CTE_STUDENTS_2018  CTE_HOURS_2018  \
# 6            3.0                3.0  ...                3.0             3.0
# 14           3.0               26.0  ...               11.0            33.0
# 15           2.0                0.0  ...                0.0             0.0
# 30           3.0                3.0  ...                0.0             0.0
# 31           6.0                0.0  ...                0.0             0.0
#
#     CTE_AVG_2018  ALL_STUDENTS_2018  ALL_HOURS_2018  ALL_AVG_2018  \
# 6            3.0                3.0             3.0           3.0
# 14           3.0               11.0            33.0           3.0
# 15           0.0                0.0             0.0           0.0
# 30           0.0                0.0             0.0           0.0
# 31           0.0                0.0             0.0           0.0
#
#          District  TEA District Type  TEA Description  Course Type
# 6      CAYUGA ISD                  H            Rural     CTE/Tech
# 14  FRANKSTON ISD                  H            Rural     CTE/Tech
# 15  FRANKSTON ISD                  H            Rural     CTE/Tech
# 30     NECHES ISD                  H            Rural     CTE/Tech
# 31     NECHES ISD                  H            Rural     CTE/Tech
#
# [5 rows x 31 columns]

# %%
tea_groups = cte_focus.groupby('TEA Description')

total_hours = tea_groups['CTE_HOURS_2018'].sum()
tea_chart = total_hours.plot(kind="bar", title="Total CTE Hours by Type of District")
tea_chart.set_xlabel("TEA Description")
tea_chart.set_ylabel("Total Number of Hours")
plt.xticks(rotation=40, ha="right")

plt.savefig("Images/DistrictData")
plt.show()
